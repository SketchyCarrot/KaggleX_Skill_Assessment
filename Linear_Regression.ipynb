# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from copy import deepcopy

# %%
dff = pd.read_csv("C:\\Users\\91909\\Downloads\\train.csv\\train.csv")
dss = pd.read_csv("C:\\Users\\91909\\Downloads\\test.csv\\test.csv")

# %%
dff
# Out:
#           id    brand                             model  model_year  milage  \
# 0          0     Ford                      F-150 Lariat        2018   74349
# 1          1      BMW                             335 i        2007   80000
# 2          2   Jaguar                         XF Luxury        2009   91491
# 3          3      BMW                      X7 xDrive40i        2022    2437
# 4          4  Pontiac                     Firebird Base        2001  111000
# ...      ...      ...                               ...         ...     ...
# 54268  54268      BMW                      X6 xDrive50i        2017   29000
# 54269  54269     Audi                   A4 2.0T Premium        2015   94634
# 54270  54270  Porsche                         Cayenne S        2013   40989
# 54271  54271  Porsche                 911 Carrera 4 GTS        2023    1518
# 54272  54272     Audi  A5 Sportback S line Premium Plus        2021   35000
#
# ...

# %%
dff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54273 entries, 0 to 54272
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            54273 non-null  int64
#  1   brand         54273 non-null  object
#  2   model         54273 non-null  object
#  3   model_year    54273 non-null  int64
#  4   milage        54273 non-null  int64
#  5   fuel_type     54273 non-null  object
#  6   engine        54273 non-null  object
#  7   transmission  54273 non-null  object
#  8   ext_col       54273 non-null  object
#  9   int_col       54273 non-null  object
#  10  accident      54273 non-null  object
#  11  clean_title   54273 non-null  object
#  12  price         54273 non-null  int64
# dtypes: int64(4), object(9)
# memory usage: 5.4+ MB

# %%
dff.columns
# Out:
# Index(['id', 'brand', 'model', 'model_year', 'milage', 'fuel_type', 'engine',
#        'transmission', 'ext_col', 'int_col', 'accident', 'clean_title',
#        'price'],
#       dtype='object')

# %%
df = deepcopy(dff[['brand', 'model', 'model_year', 'milage', 'fuel_type', 'engine',
       'transmission', 'ext_col', 'int_col', 'accident', 'clean_title',
       'price']])

# %%
df
# Out:
#          brand                             model  model_year  milage  \
# 0         Ford                      F-150 Lariat        2018   74349
# 1          BMW                             335 i        2007   80000
# 2       Jaguar                         XF Luxury        2009   91491
# 3          BMW                      X7 xDrive40i        2022    2437
# 4      Pontiac                     Firebird Base        2001  111000
# ...        ...                               ...         ...     ...
# 54268      BMW                      X6 xDrive50i        2017   29000
# 54269     Audi                   A4 2.0T Premium        2015   94634
# 54270  Porsche                         Cayenne S        2013   40989
# 54271  Porsche                 911 Carrera 4 GTS        2023    1518
# 54272     Audi  A5 Sportback S line Premium Plus        2021   35000
#
#            fuel_type                                             engine  \
# ...

# %%
df.brand = df.brand.astype('category').cat.codes
df.model = df.model.astype('category').cat.codes
df.fuel_type = df.fuel_type.astype('category').cat.codes
df.engine = df.engine.astype('category').cat.codes
df.transmission = df.transmission.astype('category').cat.codes
df.ext_col = df.ext_col.astype('category').cat.codes
df.int_col = df.int_col.astype('category').cat.codes
df.accident = df.accident.astype('category').cat.codes
df.clean_title = df.fuel_type.astype('category').cat.codes

# %%
df
# Out:
#        brand  model  model_year  milage  fuel_type  engine  transmission  \
# 0         14    644        2018   74349          2     719             2
# 1          4     49        2007   80000          2     534            18
# 2         21   1771        2009   91491          2     541            14
# 3          4   1748        2022    2437          3     646            43
# 4         40    693        2001  111000          2     219            34
# ...      ...    ...         ...     ...        ...     ...           ...
# 54268      4   1745        2017   29000          2     856            27
# 54269      3    165        2015   94634          1     266            14
# 54270     41    421        2013   40989          2     817            43
# 54271     41    142        2023    1518          2     762            29
# 54272      3    176        2021   35000          3     372            27
#
#        ext_col  int_col  accident  clean_title   price
# ...

# %%
x_train = df.to_numpy()[:, :-1]
y_train = df.to_numpy()[:, -1]

model = LinearRegression()
model.fit(x_train, y_train)
# y_predict = model.predict(x_test)
# rmse = np.sqrt(mean_squared_error(y_test, y_predict))
# ac = model.score(x_test, y_test)
model
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([ 1.38439033e+02, -1.39761031e+00,  1.01310381e+03, -2.07843161e-01,
#        -1.23524304e+03,  3.98480115e+01, -2.70347922e+01, -2.28640309e+00,
#         6.49447544e+01,  5.28719005e+03, -1.23524304e+03])

# %%
df['prediction'] = model.predict(x_train)
df
# Out:
#        brand  model  model_year  milage  fuel_type  engine  transmission  \
# 0         14    644        2018   74349          2     719             2
# 1          4     49        2007   80000          2     534            18
# 2         21   1771        2009   91491          2     541            14
# 3          4   1748        2022    2437          3     646            43
# 4         40    693        2001  111000          2     219            34
# ...      ...    ...         ...     ...        ...     ...           ...
# 54268      4   1745        2017   29000          2     856            27
# 54269      3    165        2015   94634          1     266            14
# 54270     41    421        2013   40989          2     817            43
# 54271     41    142        2023    1518          2     762            29
# 54272      3    176        2021   35000          3     372            27
#
#        ext_col  int_col  accident  clean_title   price    prediction
# ...

# %%
mean_absolute_error(df['price'], df['prediction'])
# Out:
# 19589.4768872285

# %%
dss
# Out:
#           id          brand  \
# 0      54273  Mercedes-Benz
# 1      54274          Lexus
# 2      54275  Mercedes-Benz
# 3      54276           Land
# 4      54277            BMW
# ...      ...            ...
# 36178  90451            GMC
# 36179  90452      Chevrolet
# 36180  90453         Toyota
# 36181  90454        Lincoln
# 36182  90455      Chevrolet
#
#                                                    model  model_year  milage  \
# 0                                          E-Class E 350        2014   73000
# 1                                            RX 350 Base        2015  128032
# 2                                          C-Class C 300        2015   51983
# 3      Rover Range Rover 5.0L Supercharged Autobiogra...        2018   29500
# 4                                           X6 xDrive40i        2020   90000
# ...                                                  ...         ...     ...
# 36178                                       Yukon Denali        2019    4500
# ...

# %%
ds = deepcopy(dss[['brand', 'model', 'model_year', 'milage', 'fuel_type', 'engine',
       'transmission', 'ext_col', 'int_col', 'accident', 'clean_title']])

# %%
ds.brand = ds.brand.astype('category').cat.codes
ds.model = ds.model.astype('category').cat.codes
ds.fuel_type = ds.fuel_type.astype('category').cat.codes
ds.engine = ds.engine.astype('category').cat.codes
ds.transmission = ds.transmission.astype('category').cat.codes
ds.ext_col = ds.ext_col.astype('category').cat.codes
ds.int_col = ds.int_col.astype('category').cat.codes
ds.accident = ds.accident.astype('category').cat.codes
ds.clean_title = ds.fuel_type.astype('category').cat.codes

# %%
ds
# Out:
#        brand  model  model_year  milage  fuel_type  engine  transmission  \
# 0         34    528        2014   73000          2     544            33
# 1         26   1246        2015  128032          2     410            26
# 2         34    317        2015   51983          2     311            20
# 3         25   1318        2018   29500          2     911            42
# 4          4   1710        2020   90000          2     633            26
# ...      ...    ...         ...     ...        ...     ...           ...
# 36178     15   1763        2019    4500          2     807             2
# 36179      9   1481        2004  185000          2     473             7
# 36180     49    480        2011  116000          2      30            11
# 36181     27   1082        2019   39000          2     843             2
# 36182      9   1575        2012  162731          1     601            33
#
#        ext_col  int_col  accident  clean_title
# ...

# %%
x_test = ds.to_numpy()
x_test
# Out:
# array([[  34,  528, 2014, ...,    8,    1,    2],
#        [  26, 1246, 2015, ...,   10,    1,    2],
#        [  34,  317, 2015, ...,  107,    1,    2],
#        ...,
#        [  49,  480, 2011, ...,   53,    1,    2],
#        [  27, 1082, 2019, ...,   82,    1,    2],
#        [   9, 1575, 2012, ...,   10,    0,    1]], dtype=int64)

# %%
dss['prediction'] = model.predict(x_test)
dss
# Out:
#           id          brand  \
# 0      54273  Mercedes-Benz
# 1      54274          Lexus
# 2      54275  Mercedes-Benz
# 3      54276           Land
# 4      54277            BMW
# ...      ...            ...
# 36178  90451            GMC
# 36179  90452      Chevrolet
# 36180  90453         Toyota
# 36181  90454        Lincoln
# 36182  90455      Chevrolet
#
#                                                    model  model_year  milage  \
# 0                                          E-Class E 350        2014   73000
# 1                                            RX 350 Base        2015  128032
# 2                                          C-Class C 300        2015   51983
# 3      Rover Range Rover 5.0L Supercharged Autobiogra...        2018   29500
# 4                                           X6 xDrive40i        2020   90000
# ...                                                  ...         ...     ...
# 36178                                       Yukon Denali        2019    4500
# ...

# %%
dss[['id', 'prediction']].to_csv('My_Model.csv', index = False)
